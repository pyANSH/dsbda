# %% [markdown]
# Data Visualization III
# Download the Iris flower dataset or any other dataset into a DataFrame. (e.g.,
# https://archive.ics.uci.edu/ml/datasets/Iris ). Scan the dataset and give the inference as:
# 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# 3. Create a box plot for each feature in the dataset.
# 4. Compare distributions and identify outliers.

# %%
import pandas as pd 
import seaborn as sn

dt = pd.read_csv('https://raw.githubusercontent.com/pyANSH/dsbda/main/dataset/iris_p6-p10.csv')

# %%
dt.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# Out:
# (150, 5)

# %%
dt2 = dt
dt2 = dt.groupby('variety').describe().transpose()
dt2
# Out:
# variety                Setosa  Versicolor  Virginica
# sepal.length count  50.000000   50.000000  50.000000
#              mean    5.006000    5.936000   6.588000
#              std     0.352490    0.516171   0.635880
#              min     4.300000    4.900000   4.900000
#              25%     4.800000    5.600000   6.225000
#              50%     5.000000    5.900000   6.500000
#              75%     5.200000    6.300000   6.900000
#              max     5.800000    7.000000   7.900000
# sepal.width  count  50.000000   50.000000  50.000000
#              mean    3.428000    2.770000   2.974000
#              std     0.379064    0.313798   0.322497
#              min     2.300000    2.000000   2.200000
#              25%     3.200000    2.525000   2.800000
#              50%     3.400000    2.800000   3.000000
#              75%     3.675000    3.000000   3.175000
#              max     4.400000    3.400000   3.800000
# petal.length count  50.000000   50.000000  50.000000
# ...

# %%
sn.histplot(x='petal.width',y='petal.length',hue ='variety', data = dt)
# Out:
# <AxesSubplot:xlabel='petal.width', ylabel='petal.length'>

# %%
sn.scatterplot(x='petal.width',y='petal.length',hue ='variety', data = dt)
# Out:
# <AxesSubplot:xlabel='petal.width', ylabel='petal.length'>
