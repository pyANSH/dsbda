# %% [markdown]
# . Descriptive Statistics - Measures of Central Tendency and variability
# Perform the following operations on any open source dataset (e.g., data.csv)
# 1. Provide summary statistics (mean, median, minimum, maximum, standard deviation) for
# a dataset (age, income etc.) with numeric variables grouped by one of the qualitative
# (categorical) variable. For example, if your categorical variable is age groups and
# quantitative variable is income, then provide summary statistics of income grouped by
# the age groups. Create a list that contains a numeric value for each response to the
# categorical variable.
# 2. Write a Python program to display some basic statistical details like percentile, mean,
# standard deviation etc. of the species of ‘Iris-setosa’, ‘Iris-versicolor’ and ‘Irisversicolor’ of iris.csv dataset.
# Provide the codes with outputs and explain everything that you do in this step.

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

dt = pd.read_csv("https://raw.githubusercontent.com/pyANSH/dsbda/main/dataset/p3.csv")

# %%
dt.head()
# Out:
#            earn  height     sex   race  ed  age
# 0  79571.299011   73.89    male  white  16   49
# 1  96396.988643   66.23  female  white  16   62
# 2  48710.666947   63.77  female  white  16   33
# 3  80478.096153   63.22  female  other  16   95
# 4  82089.345498   63.08  female  white  17   43

# %%
dt.describe()
# Out:
#                 earn       height           ed          age
# count    1379.000000  1379.000000  1379.000000  1379.000000
# mean    32446.292622    66.592640    13.354605    45.328499
# std     31257.070006     3.818108     2.438741    15.789715
# min       -98.580489    57.340000     3.000000    22.000000
# 25%     10538.790721    63.720000    12.000000    33.000000
# 50%     26877.870178    66.050000    13.000000    42.000000
# 75%     44506.215336    69.315000    15.000000    55.000000
# max    317949.127955    77.210000    18.000000    95.000000

# %%
from scipy import stats

col = []
col.extend(dt.columns)
col.pop(2)
col.pop(2)
col
# Out:
# ['earn', 'height', 'ed', 'age']

# %%
dt2 = dt
dt2[col] = stats.zscore(dt2[col])
dt2.head()
# Out:
#        earn    height     sex   race        ed       age
# 0  1.508206  1.911944    male  white  1.085131  0.232609
# 1  2.046702 -0.095013  female  white  1.085131  1.056229
# 2  0.520531 -0.739545  female  white  1.085131 -0.781076
# 3  1.537228 -0.883648  female  other  1.085131  3.146955
# 4  1.588795 -0.920329  female  white  1.495328 -0.147523

# %%
# from sklearn.datasets import Iris
dt3 = pd.read_csv("https://raw.githubusercontent.com/pyANSH/dsbda/main/dataset/iris_p6-p10.csv")
dt3.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
gb = dt3.groupby('variety').describe()
gb.transpose()
# Out:
# variety                Setosa  Versicolor  Virginica
# sepal.length count  50.000000   50.000000  50.000000
#              mean    5.006000    5.936000   6.588000
#              std     0.352490    0.516171   0.635880
#              min     4.300000    4.900000   4.900000
#              25%     4.800000    5.600000   6.225000
#              50%     5.000000    5.900000   6.500000
#              75%     5.200000    6.300000   6.900000
#              max     5.800000    7.000000   7.900000
# sepal.width  count  50.000000   50.000000  50.000000
#              mean    3.428000    2.770000   2.974000
#              std     0.379064    0.313798   0.322497
#              min     2.300000    2.000000   2.200000
#              25%     3.200000    2.525000   2.800000
#              50%     3.400000    2.800000   3.000000
#              75%     3.675000    3.000000   3.175000
#              max     4.400000    3.400000   3.800000
# petal.length count  50.000000   50.000000  50.000000
# ...

# %%
sn.jointplot(x = 'variety', y = 'petal.width', data = dt3)
